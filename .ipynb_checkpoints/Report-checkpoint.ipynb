# %% [markdown]
# # Held-out log-likelihood

# %%
import numpy as np
import matplotlib.pyplot as plt

def plotLL(K, inroot, heldoutroot, expset):
    """
    Inputs:
        expset: list of experimental seeds
    Outputs:
        plots LL of LDA 1/K and SB_LDA versus number of minibatches
    Remarks: 
        all experiments are expected to run until completion i.e. 
        the same number of iterations.
    """
    
    # Load and compute average LDA 1/K
    ldadir = "ldaK" + str(K) + "_" + inroot + "_" + heldoutroot
    ldaLL = []
    ## load experiments
    for seed in expset:
        ldapath = ldadir + "/_" + str(seed) + ".csv"
        result = np.loadtxt(ldapath)
        ldabatchcounts = result[:,0]
        ldaLL.append(result[:,2])
    ldaLL = np.array(ldaLL) # shape len(expset) x maxbatchcount
    ldaavg = np.mean(ldaLL, axis=0) # shape (maxbatchcount,)
    ldaerr = np.std(ldaLL, axis=0) # shape (maxbatchcount,)
    
    # Load and compute average SB_LDA
    sbdir = "sbldaK" + str(K) + "_" + inroot + "_" + heldoutroot
    sbLL = []
    ## load experiments
    for seed in expset:
        sbpath = sbdir + "/_" + str(seed) + ".csv"
        result = np.loadtxt(sbpath)
        sbbatchcounts = result[:,0]
        sbLL.append(result[:,2])
    sbLL = np.array(sbLL) # shape len(expset) x len(batchcounts)
    sbavg = np.mean(sbLL, axis=0) # shape (len(batchcounts),)
    sberr = np.std(sbLL, axis=0) # shape (len(batchcounts),)
    
    fig = plt.figure()
    plt.errorbar(ldabatchcounts, ldaavg, yerr=ldaerr,label='LDA 1/K')
    plt.errorbar(sbbatchcounts, sbavg, yerr=sberr,label='SB-LDA')
    plt.title('Held-out LL vs # mini-batches')
    plt.xlabel('Number of mini-batches')
    plt.ylabel('Held-out log-likelihood')
    plt.legend()
    plt.show()
    
    return

# %%
plotLL(100, "wiki10k","wiki1k", range(1,11))

# %% [markdown]
# # Inferred topics

# %%
import numpy as np
import pandas as pd

# %%
def printtopics(vocabfile, lambdafile, normalized, threshold, displaycount):
    vocab = open(vocabfile).readlines()
    testlambda = np.loadtxt(lambdafile)
    sigtopics = 0
    df = pd.DataFrame() 
    for k in range(0, len(testlambda)):
        lambdak = list(testlambda[k, :])
        lambdak = [round(i,1) for i in lambdak]
        # report marginal probabilities instead of Dirichlet parameters
        if (normalized):
            lambdak = lambdak / sum(lambdak)
        temp = list(zip(lambdak, list(range(0, len(lambdak)))))
        temp = sorted(temp, key = lambda x: x[0], reverse=True)
        # plot topics with parameters exceeding the threshold
        if (temp[0][0] >= threshold):
            colname = 'topic %d' % (k)
            coldata = [(str.strip(vocab[temp[i][1]]), temp[i][0]) for i in range(0, displaycount)]
            df[colname] = coldata
    print("Discovered %d significant topics at threshold %.2f" %(len(df.columns),threshold))
    return df

# %%
vocabfile = "dictnostops.txt"
lambdafile = "ldaK100_D16_wiki10k_wiki1k/lambda-100.dat"
normalized = 0
threshold = 200
displaycount = 10

# %%
df = printtopics(vocabfile, "ldaK100_D16_wiki10k_wiki1k/lambda-100.dat", 0, 100, 10)
df
# Out:
# Discovered  10 significant topics at threshold 100.00
#              topic 11            topic 12           topic 21         topic 31  \
# 0        (der, 620.1)     (first, 5566.2)  (squadron, 386.6)    (mine, 120.6)
# 1       (book, 561.5)       (new, 4391.5)      (navy, 157.1)   (copper, 21.8)
# 2        (van, 497.2)       (two, 3563.2)     (royal, 149.6)    (mines, 19.8)
# 3        (die, 410.0)    (county, 3229.9)     (knight, 97.2)   (deepest, 9.0)
# 4       (life, 395.5)    (school, 3225.4)   (prussian, 95.6)  (district, 5.0)
# 5  (published, 387.2)  (national, 2972.1)  (commander, 32.4)      (gold, 3.4)
# 6    (stories, 379.8)     (years, 2954.1)      (naval, 26.3)    (system, 3.2)
# 7        (und, 318.8)      (year, 2904.6)        (col, 25.2)    (occurs, 3.1)
# 8    (written, 316.7)     (state, 2733.0)   (dominion, 22.9)      (born, 3.0)
# 9       (play, 294.8)     (march, 2666.0)    (command, 22.3)     (first, 2.9)
#
#             topic 40           topic 44             topic 56  \
# 0    (music, 1352.9)     (line, 2150.1)      (score, 6142.9)
# 1     (band, 1292.5)   (series, 1428.6)       (team, 4204.9)
# 2     (song, 1134.7)      (new, 1401.1)       (seed, 1006.6)
# 3  (released, 517.2)  (company, 1229.7)       (round, 531.9)
# 4      (rock, 471.0)    (world, 1218.8)       (final, 348.5)
# 5     (songs, 398.3)     (road, 1009.1)  (attendance, 331.3)
# 6    (single, 323.6)    (street, 975.5)     (indiana, 243.6)
# 7   (turkish, 308.9)   (station, 926.5)       (bills, 125.1)
# 8      (live, 285.7)     (built, 764.5)       (report, 89.4)
# 9       (die, 276.9)       (two, 709.6)        (lions, 87.7)
#
#            topic 60          topic 62          topic 66             topic 72  \
# 0    (pride, 190.7)    (ship, 1025.0)    (tiger, 175.2)       (town, 1779.7)
# 1    (kansas, 91.4)    (ships, 476.4)      (rev, 101.6)         (max, 944.5)
# 2     (louis, 90.5)  (service, 137.4)       (par, 80.1)  (population, 857.5)
# 3   (florida, 83.2)   (vessel, 134.3)  (electric, 69.1)    (district, 607.5)
# 4     (saint, 81.5)    (fleet, 119.0)     (shoes, 58.7)     (village, 533.0)
# 5      (pool, 54.3)     (class, 98.1)       (cat, 52.9)        (area, 332.1)
# 6       (sky, 51.0)   (vessels, 96.5)      (bend, 52.7)      (parish, 215.6)
# 7     (grand, 43.6)     (naval, 74.5)     (steel, 46.0)         (age, 199.3)
# 8      (sort, 29.3)       (oil, 72.4)    (ground, 41.3)   (elevation, 197.6)
# 9  (missouri, 28.0)       (sea, 66.0)    (jungle, 40.9)    (province, 195.0)
#
#            topic 76             topic 77            topic 85  \
# 0     (text, 124.8)      (people, 870.2)     (party, 1981.5)
# 1  (chapters, 10.2)       (group, 813.6)   (division, 870.6)
# 2   (chapter, 10.0)        (city, 783.9)   (election, 839.1)
# 3      (pages, 5.4)         (new, 760.7)    (brigade, 755.9)
# 4   (presents, 4.8)     (history, 741.8)        (act, 713.5)
# 5     (states, 4.5)         (air, 728.2)  (political, 662.7)
# 6      (shift, 4.4)  (literature, 721.1)     (battle, 639.8)
# 7   (universe, 4.1)        (work, 661.6)   (minister, 592.4)
# 8    (concept, 3.7)     (program, 528.7)       (lord, 585.9)
# 9        (two, 3.4)     (chinese, 517.6)     (valley, 502.4)
#
#               topic 87           topic 88           topic 90
# 0      (goals, 1476.7)   (january, 783.3)  (species, 1017.5)
# 1       (clubs, 694.1)  (november, 531.5)    (family, 486.5)
# 2       (years, 558.9)      (king, 500.3)    (island, 445.3)
# 3        (data, 395.9)       (san, 444.6)     (black, 439.8)
# 4      (report, 342.5)   (october, 384.7)   (forests, 422.1)
# 5        (sort, 292.6)      (died, 328.2)       (sea, 387.2)
# 6  (attendance, 254.0)    (louise, 305.8)     (found, 387.0)
# 7         (cup, 222.5)    (bishop, 248.7)    (forest, 364.5)
# 8        (club, 218.3)    (august, 236.3)     (genus, 350.1)
# 9        (loan, 206.2)   (brother, 223.2)  (tropical, 315.9)

# %%
df = printtopics(vocabfile, "sbldaK100_D16_wiki10k_wiki1k/lambda-100.dat", 0, 100, 10)
df
# Out:
# Discovered  10 significant topics at threshold 100.00
#             topic 0             topic 1             topic 2  \
# 0    (week, 4438.8)    (series, 1913.8)     (nature, 940.2)
# 1   (first, 4408.1)      (best, 1851.3)     (church, 692.5)
# 2     (new, 3809.6)     (music, 1823.9)    (century, 593.7)
# 3   (years, 3206.1)       (new, 1551.1)       (work, 480.3)
# 4     (two, 3148.3)      (sort, 1348.1)      (cells, 453.5)
# 5   (color, 2969.3)  (released, 1284.7)     (people, 441.3)
# 6    (time, 2860.5)     (first, 1159.6)   (attitude, 406.6)
# 7   (state, 2491.6)      (song, 1090.4)      (roman, 392.9)
# 8    (city, 2425.3)        (cat, 939.8)  (published, 380.4)
# 9  (united, 2423.9)       (love, 871.7)      (found, 376.0)
#
#                topic 3             topic 4
# 0     (score, 11240.1)     (battle, 199.3)
# 1       (team, 6785.5)      (ships, 181.0)
# 2       (seed, 3170.3)       (lord, 167.0)
# 3       (round, 952.4)   (squadron, 160.9)
# 4      (report, 787.7)     (attack, 154.1)
# 5  (attendance, 617.3)    (control, 154.0)
# 6       (goals, 300.1)    (command, 151.7)
# 7         (van, 178.4)  (commander, 145.5)
# 8     (section, 143.9)       (army, 144.7)
# 9      (second, 134.0)      (civil, 141.2)
